# %%
# imports
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
import random as rn

# %%
lvls_titles = ["Простые", "Усложнённые", "Сложные"]
lvls = {"Простые": 3, "Усложнённые": 5, "Сложные": 7}
tickets_cnt = 50
path_to_tickets_dir = "Problems"
path_to_info = "Ограничения.pdf"

# %%
#read pdf
output_string = StringIO()
with open(path_to_info, 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)
info = output_string.getvalue()
print(info)
# Out:
# Предисловие
#
# В сборнике представлены задачи экзамена по аналитической геометрии
# и линейной алгебре для всех направлений подготовки бакалавров в МТУ-
# СИ.
#
# Задачи разбиты на семь групп для формирования билетов из семи зада-
# ний каждый. При компоновке билетов следует учитывать сложность каж-
# дого вопроса, а также избегать повторов или близости формулировок.
#
# Задания группы 1
#
# Простые: 1, 11, 16, 19, 111, 120, 121, 122, 123, 124, 125, 127, 128, 129, 130,
#
# 132, 133, 134, 136, 137, 138, 141, 142, 145, 146, 147, 148 (27 заданий).
#
# Усложнённые: 12, 13, 14, 110, 112, 116, 117, 118, 119, 126, 135, 139, 140,
#
# 143 (14 заданий).
#
# Сложные: 15, 17, 18, 113, 114, 115, 131, 144, 149 (9 заданий).
#
# Задания группы 2
#
# Простые: 212, 213, 214, 216, 219, 220, 221, 222, 223, 224, 234, 243, 244,
#
# 245, 246, 247, 248, 249 (18 заданий).
#
# Усложнённые: 25, 26, 27, 28, 29, 210, 211, 215, 218, 225, 226, 227, 228, 229,
#
# 230, 231, 232, 233, 235, 236, 237, 241 (22 задания).
#
# Сложные: 2, 21, 22, 23, 24, 217, 238, 239, 240, 242 (10 заданий).
#
# Задания группы 3
#
# Простые: 310, 311, 312, 313, 314, 326, 327, 340, 341, 342, 345, 349 (12
#
# заданий).
#
# Усложнённые: 33, 34, 35, 36, 37, 38, 39, 315, 316, 317, 318, 319, 320, 321,
#
# 323, 331, 332, 333, 334, 335, 339, 346, 347, 348 (24 задания).
#
# Сложные: 3, 31, 32, 322, 324, 325, 328, 329, 330, 336, 337, 338, 343, 344
#
# (14 заданий).
#
# Задания группы 4
#
# Простые: 44, 49, 410, 411, 413, 414, 415, 416, 417, 426, 427, 432, 433, 436,
#
# 437, 442, 443, 444 (18 заданий).
#
# Усложнённые: 41, 42, 412, 418, 419, 421, 424, 425, 428, 429, 430, 431, 434,
#
# 435, 438, 439, 440, 441, 445, 446 (20 заданий).
#
# 2
#
# Сложные: 4, 43, 45, 46, 47, 48, 420, 422, 423, 447, 448, 449 (12 заданий).
#
# Задания группы 5
#
# Простые: 5, 517, 518, 519, 522, 525, 526, 527 (8 заданий).
# Усложнённые: 51, 52, 54, 55, 56, 57, 58, 59, 510, 511, 512, 513, 514, 528,
#
# 529, 530, 531, 532, 534, 535, 536, 537, 538, 539 (24 задания).
#
# Сложные: 53, 515, 516, 520, 521, 523, 524, 533, 540, 541, 542, 543, 544,
#
# 545, 546, 547, 548, 549 (18 заданий).
#
# Задания группы 6
#
# Простые: 6, 61, 62, 63, 64, 611, 612, 613, 614, 615, 618, 619, 620, 621, 622,
#
# 623, 624, 625, 626, 627, 628, 629, 643, 644, 647 (25 заданий).
#
# Усложнённые: 65, 66, 67, 68, 645, 646, 648, 649 (8 заданий).
# Сложные: 69, 610, 616, 617, 630, 631, 632, 633, 634, 635, 636, 637, 638,
#
# 639, 640, 641, 642 (17 заданий).
#
# Задания группы 7
#
# Простые: 7, 71, 72, 73, 74, 75, 76, 714, 715, 720, 721, 722, 723, 740 (14
#
# заданий).
#
# Усложнённые: 77, 78, 79, 710, 712, 713, 724, 725, 726, 727, 728, 729, 730,
#
# 731, 732, 733, 734, 735, 736, 737, 738, 739, 743 (23 задания).
#
# Сложные: 711, 716, 717, 718, 719, 741, 742, 744, 745, 746, 747, 748, 749
#
# (13 заданий).
#
# Следует исключать в одном билете:
#
# I. 19, 110,111;
#
# 312, 313, 334, 335;
#
# 414, 415, 416, 417.
#
# II. 112;
# 63, 64, 65.
#
# 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 241;
#
# 6, 61, 62,
#
# III. 18;
#
# 66, 67, 68, 69, 610.
#
# IV. 121, 122;
#
# 311, 332, 333;
#
# 49, 410, 411, 412, 413, 418, 419, 420.
#
# V.127, 132, 133, 134, 136, 142, 143;
#
# 314, 339;
#
# 426, 427, 428, 429, 430,
#
# 431;
#
# 77, 78, 79, 710, 740.
#
# VI. 129, 130;
#
# 323, 324, 349.
#
# VII. 131;
#
# 41,42,45,46;
#
# 637.
#
# VIII. 149;
#
# 2, 21, 22, 23, 24;
#
# 638, 639, 640.
#
# IX. 12, 13, 14, 120, 148;
#
# 211, 212.
#
# X. 113, 114, 115, 142, 143, 144, 145, 146, 147;
#
# 219;
#
# 326, 327, 328, 329,
#
# 3
#
# 330.
#
# XI. 241, 242, 243, 244, 245, 246, 247, 248, 249;
#
# 4.
#
# XII. 3, 31, 32, 33, 34, 35, 36, 37, 38, 39, 310, 315, 316, 317, 318, 319;
#
# 434,
#
# 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446.
#
# XIII. 311, 312, 313, 332, 333, 334, 335, 340, 341, 342;
#
# 49, 410, 411, 412,
#
# 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423.
#
# 4

# %%
info.replace("\n", " ")
sorted_task = {}
for i in info.split("Задания группы"):
    txt = i.replace("\n", " ")
    txt = txt.split("Следует исключать в одном билете")[0].strip()
    if not txt[0].isdigit():
        continue
    task_group = int(txt.split()[0])
    sorted_task[task_group] = {}
    lvl_group = ""
    task_elements = txt.split()[1:]
    for i in task_elements:
        # print(f"!!{i}!!\n----")
        for lvl in lvls_titles:
            if i[:-1] == lvl:
                lvl_group = lvl
                sorted_task[task_group][lvl_group] = []
                break
        if lvl_group and i[0].isdigit():
            num = int(i.strip().split(",")[0].strip())
            sorted_task[task_group][lvl_group].append(num)

# %%
print(sorted_task)
# Out:
# {1: {'Простые': [1, 11, 16, 19, 111, 120, 121, 122, 123, 124, 125, 127, 128, 129, 130, 132, 133, 134, 136, 137, 138, 141, 142, 145, 146, 147, 148], 'Усложнённые': [12, 13, 14, 110, 112, 116, 117, 118, 119, 126, 135, 139, 140, 143], 'Сложные': [15, 17, 18, 113, 114, 115, 131, 144, 149]}, 2: {'Простые': [212, 213, 214, 216, 219, 220, 221, 222, 223, 224, 234, 243, 244, 245, 246, 247, 248, 249], 'Усложнённые': [25, 26, 27, 28, 29, 210, 211, 215, 218, 225, 226, 227, 228, 229, 230, 231, 232, 233, 235, 236, 237, 241], 'Сложные': [2, 21, 22, 23, 24, 217, 238, 239, 240, 242]}, 3: {'Простые': [310, 311, 312, 313, 314, 326, 327, 340, 341, 342, 345, 349], 'Усложнённые': [33, 34, 35, 36, 37, 38, 39, 315, 316, 317, 318, 319, 320, 321, 323, 331, 332, 333, 334, 335, 339, 346, 347, 348], 'Сложные': [3, 31, 32, 322, 324, 325, 328, 329, 330, 336, 337, 338, 343, 344]}, 4: {'Простые': [44, 49, 410, 411, 413, 414, 415, 416, 417, 426, 427, 432, 433, 436, 437, 442, 443, 444], 'Усложнённые': [41, 42, 412, 418, 419, 421, 424, 425, 428, 429, 430, 431, 434, 435, 438, 439, 440, 441, 445, 446, 2], 'Сложные': [4, 43, 45, 46, 47, 48, 420, 422, 423, 447, 448, 449]}, 5: {'Простые': [5, 517, 518, 519, 522, 525, 526, 527], 'Усложнённые': [51, 52, 54, 55, 56, 57, 58, 59, 510, 511, 512, 513, 514, 528, 529, 530, 531, 532, 534, 535, 536, 537, 538, 539], 'Сложные': [53, 515, 516, 520, 521, 523, 524, 533, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549]}, 6: {'Простые': [6, 61, 62, 63, 64, 611, 612, 613, 614, 615, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 643, 644, 647], 'Усложнённые': [65, 66, 67, 68, 645, 646, 648, 649], 'Сложные': [69, 610, 616, 617, 630, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642]}, 7: {'Простые': [7, 71, 72, 73, 74, 75, 76, 714, 715, 720, 721, 722, 723, 740], 'Усложнённые': [77, 78, 79, 710, 712, 713, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 743], 'Сложные': [711, 716, 717, 718, 719, 741, 742, 744, 745, 746, 747, 748, 749]}}

# %%
def get_size_sorted_task(sorted_task, lvls):

    size_sorted_task = {}
    for task in sorted_task:
        avg_lvl = 0
        task_cnt = 0
        size_sorted_task[task] = {}
        for task_lvl in sorted_task[task]:
            ln = len(sorted_task[task][task_lvl])
            size_sorted_task[task][task_lvl] = ln
            task_cnt += ln
            avg_lvl += lvls[task_lvl] * ln
        size_sorted_task[task]["avg"] = round(avg_lvl / task_cnt, 3)
    return size_sorted_task

size_sorted_task = get_size_sorted_task(sorted_task)
print(size_sorted_task)
# Out:
# {1: {'Простые': 27, 'Усложнённые': 14, 'Сложные': 9, 'avg': 4.28}, 2: {'Простые': 18, 'Усложнённые': 22, 'Сложные': 10, 'avg': 4.68}, 3: {'Простые': 12, 'Усложнённые': 24, 'Сложные': 14, 'avg': 5.08}, 4: {'Простые': 18, 'Усложнённые': 21, 'Сложные': 12, 'avg': 4.765}, 5: {'Простые': 8, 'Усложнённые': 24, 'Сложные': 18, 'avg': 5.4}, 6: {'Простые': 25, 'Усложнённые': 8, 'Сложные': 17, 'avg': 4.68}, 7: {'Простые': 14, 'Усложнённые': 23, 'Сложные': 13, 'avg': 4.96}}

# %%
avg = 0
for task in sorted_task:
    avg += size_sorted_task[task]["avg"]
avg /= len(size_sorted_task)
avg
# Out:
# 4.835

# %%
ticket_batch_size = 30
avg_ticket_lvl = 5

# %%
from collections import defaultdict

def get_ticket_list_by_avg(task_dict_cnt, lvls, tickets_cnt, avg):
    # Инициализация ошибок для каждой сложности
    total_available_tasks = sum(task_dict_cnt.values())
    if total_available_tasks < tickets_cnt:
        raise ValueError(f"Недостаточно задач! Всего доступно {total_available_tasks - task_dict_cnt.get("avg", 0)}, требуется {tickets_cnt}.")
    lvls = lvls.copy()
    task_dict_cnt = task_dict_cnt.copy()

    abs_lvls_error = {lvl: abs(avg - lvls[lvl]) for lvl in lvls}
    lvls_error = {lvl: avg - lvls[lvl] for lvl in lvls}

    # Сортируем задачи по сложности (от меньшего отклонения от avg)
    sorted_error = sorted(lvls, key=lambda lvl: abs_lvls_error[lvl])
    not_chosen = tickets_cnt
    chosen_lvls = defaultdict(int)

    # Основной цикл
    while not_chosen > 0:
        # Печать текущего состояния для отладки
        print(f"avg = {avg}, s_e = {sorted_error}")

        # Проверка на пустой список
        if not sorted_error:
            break

        # Берём задачу с минимальной ошибкой
        task = sorted_error[0]  # Берём первый элемент в отсортированном списке
        task_cnt = task_dict_cnt.get(task, 0)

        # Если задача исчерпана, удаляем её из всех структур данных
        if task_cnt == 0:
            sorted_error.pop(0)  # Убираем её из отсортированного списка
            lvls_error.pop(task, None)
            abs_lvls_error.pop(task, None)
            lvls.pop(task, None)  # Удаляем также из lvls, чтобы избежать выбора
            continue

        # Выбираем задачу и уменьшаем её количество
        chosen_lvls[task] += 1
        task_dict_cnt[task] -= 1
        not_chosen -= 1

        # Обновляем среднее значение, учитывая только выбранные задачи

        avg+=lvls_error[task]

        # Пересчитываем ошибки для всех уровней на основе обновленного среднего
        abs_lvls_error = {lvl: abs(avg - lvls[lvl]) for lvl in lvls}

        # Обновляем список уровней с минимальной ошибкой
        sorted_error = sorted(lvls, key=lambda lvl: abs_lvls_error[lvl])

    return chosen_lvls

# Пример вызова функции
# Пример уровня сложности
print(size_sorted_task[4])
result = get_ticket_list_by_avg(size_sorted_task[5], lvls, 22, 6)

print(result)
# Out:
# {'Простые': 18, 'Усложнённые': 21, 'Сложные': 12, 'avg': 4.765}
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# defaultdict(<class 'int'>, {'Усложнённые': 11, 'Сложные': 11})

# %%
import random as rn

def create_task_pack(lvls_tasks_cnt, all_tasks):
    lvls_tasks_cnt = lvls_tasks_cnt.copy()  # Копируем словарь lvls_tasks_cnt
    all_tasks = all_tasks.copy()  # Копируем словарь all_tasks
    task_pack = []

    # Проходим по каждому уровню сложности
    for task_lvl, task_cnt in lvls_tasks_cnt.items():
        task_lvl_pack = all_tasks[task_lvl][:]  # Создаём копию списка задач для текущего уровня сложности

        all_tasks_cnt = len(task_lvl_pack)
        print(f"all tasks cnt {all_tasks_cnt}")
        # Выбираем нужное количество задач
        for i in range(task_cnt):
            if all_tasks_cnt == 0:  # Если задач не осталось, пропускаем
                break
            rn_task_idx = rn.randint(0, all_tasks_cnt - 1)  # Генерируем случайный индекс
            chosen_task = task_lvl_pack.pop(rn_task_idx)  # Удаляем задачу из копии списка
            task_pack.append((chosen_task, task_lvl))  # Добавляем задачу и её уровень сложности в итоговый пакет
            all_tasks_cnt -= 1  # Обновляем количество оставшихся задач

    rn.shuffle(task_pack)  # Перемешиваем итоговый список задач
    return task_pack

# %%
print("result = ",res:=create_task_pack(result, sorted_task[5]))
# print(result, sorted_task[1])
print(len(res))
print(result)
# Out:
# all tasks cnt 24
# all tasks cnt 18
# result =  [(513, 'Усложнённые'), (542, 'Сложные'), (54, 'Усложнённые'), (520, 'Сложные'), (531, 'Усложнённые'), (52, 'Усложнённые'), (532, 'Усложнённые'), (549, 'Сложные'), (546, 'Сложные'), (524, 'Сложные'), (56, 'Усложнённые'), (530, 'Усложнённые'), (545, 'Сложные'), (534, 'Усложнённые'), (521, 'Сложные'), (515, 'Сложные'), (533, 'Сложные'), (528, 'Усложнённые'), (53, 'Сложные'), (55, 'Усложнённые'), (58, 'Усложнённые'), (523, 'Сложные')]
# 22
# defaultdict(<class 'int'>, {'Усложнённые': 11, 'Сложные': 11})

# %%
def create_task_bank(mark, tickets_cnt, size_sorted_task, sorted_task, lvls):
    task_bank = {}
    for task in size_sorted_task:
        chosen_tasks_cnt = get_ticket_list_by_avg(size_sorted_task[task], lvls, tickets_cnt, mark)
        pack = create_task_pack(chosen_tasks_cnt, sorted_task[task])
        task_bank[task] = pack
    return task_bank

# %%
def create_tickets_balanced(task_bank, tickets_cnt, lvls, mark):
    # Инициализируем билеты
    tickets = {i + 1: {} for i in range(tickets_cnt)}
    # Текущая сумма сложности и кол-во задач в каждом билете
    sum_mark = {i + 1: 0 for i in range(tickets_cnt)}
    cnt_tasks = {i + 1: 0 for i in range(tickets_cnt)}

    # Идём по темам (группам заданий)
    for task in task_bank:
        candidates = task_bank[task]  # список [(task_id, lvl_name), ...], длины tickets_cnt

        # Посчитаем сложность для каждого кандидата
        candidates_with_mark = [
            (task_id, lvl_name, lvls[lvl_name]) for (task_id, lvl_name) in candidates
        ]

        # Сортируем билеты по текущей средней сложности (от самых "лёгких" к "тяжёлым")
        ticket_order = sorted(
            tickets.keys(),
            key=lambda t_id: (sum_mark[t_id] / cnt_tasks[t_id]) if cnt_tasks[t_id] > 0 else 0
        )

        # Сортируем задания по сложности (от сложных к простым)
        candidates_with_mark.sort(key=lambda x: x[2], reverse=True)

        # Раздаём: самым лёгким билетам — самые сложные задачи
        for (ticket_id, (task_id, lvl_name, task_mark)) in zip(ticket_order, candidates_with_mark):
            tickets[ticket_id][task] = (task_id, lvl_name)
            sum_mark[ticket_id] += task_mark
            cnt_tasks[ticket_id] += 1

    return tickets

# %%
def main_pipeline(tickets_cnt,mark, all_tasks, all_tasks_lvls_cnt, lvls):
    task_bank = create_task_bank(mark, tickets_cnt, all_tasks_lvls_cnt,all_tasks, lvls)
    tickets = create_tickets_balanced(task_bank, tickets_cnt, lvls, mark)
    return tickets

# %%
def get_avg_mark_by_tickets(tickets, lvls, target_mark):
    """
    tickets: {
        ticket_id: {
            local_task_idx: (task_id, lvl_name)
        }
    }
    lvls: {'Простые': 3, 'Усложнённые': 5, 'Сложные': 7}
    target_mark: целевая средняя сложность (например, 5)
    """
    tickets_stats = {}
    total_mark = 0
    total_error = 0
    max_error = 0

    for ticket_id, tasks in tickets.items():
        # считаем среднюю сложность билета
        total_mark_ticket = 0
        tasks_cnt = len(tasks)

        for _, (task_id, lvl_name) in tasks.items():
            task_mark = lvls[lvl_name]
            total_mark_ticket += task_mark

        ticket_mark = total_mark_ticket / tasks_cnt
        ticket_error = abs(target_mark - ticket_mark)

        tickets_stats[ticket_id] = {
            "mark": ticket_mark,
            "error": ticket_error,
        }

        total_mark += ticket_mark
        total_error += ticket_error
        max_error = max(max_error, ticket_error)

    tickets_cnt = len(tickets)

    return {
        "avg_mark": total_mark / tickets_cnt,
        "avg_error": total_error / tickets_cnt,
        "max_error": max_error,
        "tickets": tickets_stats,
    }

# %%
tickets = main_pipeline(20, 6, sorted_task, size_sorted_task, lvls)
# Out:
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 7, s_e = ['Усложнённые', 'Простые']
# all tasks cnt 14
# all tasks cnt 9
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# all tasks cnt 22
# all tasks cnt 10
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# all tasks cnt 24
# all tasks cnt 14
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# all tasks cnt 21
# all tasks cnt 12
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# all tasks cnt 24
# all tasks cnt 18
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 6, s_e = ['Сложные', 'Простые']
# avg = 5, s_e = ['Простые', 'Сложные']
# avg = 8, s_e = ['Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Простые']
# all tasks cnt 8
# all tasks cnt 17
# all tasks cnt 25
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# avg = 6, s_e = ['Усложнённые', 'Сложные', 'Простые']
# avg = 7, s_e = ['Сложные', 'Усложнённые', 'Простые']
# all tasks cnt 23
# all tasks cnt 13

# %%
tickets
# Out:
# {1: {1: (113, 'Сложные'),
#   2: (237, 'Усложнённые'),
#   3: (31, 'Сложные'),
#   4: (419, 'Усложнённые'),
#   5: (533, 'Сложные'),
#   6: (646, 'Усложнённые'),
#   7: (716, 'Сложные')},
#  2: {1: (144, 'Сложные'),
#   2: (27, 'Усложнённые'),
#   3: (338, 'Сложные'),
#   4: (431, 'Усложнённые'),
#   5: (546, 'Сложные'),
#   6: (66, 'Усложнённые'),
#   7: (742, 'Сложные')},
#  3: {1: (149, 'Сложные'),
#   2: (26, 'Усложнённые'),
#   3: (329, 'Сложные'),
#   4: (441, 'Усложнённые'),
#   5: (549, 'Сложные'),
#   6: (648, 'Усложнённые'),
#   7: (741, 'Сложные')},
#  4: {1: (17, 'Сложные'),
#   2: (29, 'Усложнённые'),
#   3: (330, 'Сложные'),
#   4: (429, 'Усложнённые'),
#   5: (523, 'Сложные'),
#   6: (645, 'Усложнённые'),
#   7: (746, 'Сложные')},
#  5: {1: (131, 'Сложные'),
#   2: (215, 'Усложнённые'),
#   3: (343, 'Сложные'),
#   4: (438, 'Усложнённые'),
#   5: (545, 'Сложные'),
#   6: (65, 'Усложнённые'),
#   7: (711, 'Сложные')},
#  6: {1: (114, 'Сложные'),
#   2: (232, 'Усложнённые'),
#   3: (344, 'Сложные'),
#   4: (428, 'Усложнённые'),
#   5: (541, 'Сложные'),
#   6: (649, 'Усложнённые'),
#   7: (745, 'Сложные')},
#  7: {1: (15, 'Сложные'),
#   2: (211, 'Усложнённые'),
#   3: (328, 'Сложные'),
#   4: (446, 'Усложнённые'),
#   5: (524, 'Сложные'),
#   6: (68, 'Усложнённые'),
#   7: (749, 'Сложные')},
#  8: {1: (18, 'Сложные'),
#   2: (227, 'Усложнённые'),
#   3: (3, 'Сложные'),
#   4: (42, 'Усложнённые'),
#   5: (53, 'Сложные'),
#   6: (67, 'Усложнённые'),
#   7: (748, 'Сложные')},
#  9: {1: (115, 'Сложные'),
#   2: (241, 'Усложнённые'),
#   3: (32, 'Сложные'),
#   4: (418, 'Усложнённые'),
#   5: (544, 'Сложные'),
#   6: (622, 'Простые'),
#   7: (718, 'Сложные')},
#  10: {1: (117, 'Усложнённые'),
#   2: (242, 'Сложные'),
#   3: (316, 'Усложнённые'),
#   4: (48, 'Сложные'),
#   5: (57, 'Усложнённые'),
#   6: (638, 'Сложные'),
#   7: (717, 'Сложные')},
#  11: {1: (12, 'Усложнённые'),
#   2: (240, 'Сложные'),
#   3: (332, 'Усложнённые'),
#   4: (420, 'Сложные'),
#   5: (539, 'Усложнённые'),
#   6: (635, 'Сложные'),
#   7: (732, 'Усложнённые')},
#  12: {1: (118, 'Усложнённые'),
#   2: (238, 'Сложные'),
#   3: (321, 'Усложнённые'),
#   4: (447, 'Сложные'),
#   5: (537, 'Усложнённые'),
#   6: (640, 'Сложные'),
#   7: (738, 'Усложнённые')},
#  13: {1: (14, 'Усложнённые'),
#   2: (2, 'Сложные'),
#   3: (333, 'Усложнённые'),
#   4: (449, 'Сложные'),
#   5: (513, 'Усложнённые'),
#   6: (637, 'Сложные'),
#   7: (731, 'Усложнённые')},
#  14: {1: (139, 'Усложнённые'),
#   2: (24, 'Сложные'),
#   3: (35, 'Усложнённые'),
#   4: (47, 'Сложные'),
#   5: (529, 'Усложнённые'),
#   6: (630, 'Сложные'),
#   7: (730, 'Усложнённые')},
#  15: {1: (13, 'Усложнённые'),
#   2: (21, 'Сложные'),
#   3: (34, 'Усложнённые'),
#   4: (4, 'Сложные'),
#   5: (511, 'Усложнённые'),
#   6: (636, 'Сложные'),
#   7: (725, 'Усложнённые')},
#  16: {1: (116, 'Усложнённые'),
#   2: (217, 'Сложные'),
#   3: (323, 'Усложнённые'),
#   4: (422, 'Сложные'),
#   5: (510, 'Усложнённые'),
#   6: (617, 'Сложные'),
#   7: (734, 'Усложнённые')},
#  17: {1: (143, 'Усложнённые'),
#   2: (22, 'Сложные'),
#   3: (348, 'Усложнённые'),
#   4: (43, 'Сложные'),
#   5: (536, 'Усложнённые'),
#   6: (642, 'Сложные'),
#   7: (727, 'Усложнённые')},
#  18: {1: (119, 'Усложнённые'),
#   2: (239, 'Сложные'),
#   3: (331, 'Усложнённые'),
#   4: (448, 'Сложные'),
#   5: (51, 'Усложнённые'),
#   6: (634, 'Сложные'),
#   7: (739, 'Усложнённые')},
#  19: {1: (135, 'Усложнённые'),
#   2: (23, 'Сложные'),
#   3: (38, 'Усложнённые'),
#   4: (45, 'Сложные'),
#   5: (534, 'Усложнённые'),
#   6: (69, 'Сложные'),
#   7: (743, 'Усложнённые')},
#  20: {1: (112, 'Усложнённые'),
#   2: (25, 'Усложнённые'),
#   3: (337, 'Сложные'),
#   4: (445, 'Усложнённые'),
#   5: (548, 'Сложные'),
#   6: (639, 'Сложные'),
#   7: (77, 'Усложнённые')}}

# %%
get_avg_mark_by_tickets(tickets, lvls, 6)
# Out:
# {'avg_mark': 5.985714285714288,
#  'avg_error': 0.14285714285714324,
#  'max_error': 0.14285714285714324,
#  'tickets': {1: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   2: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   3: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   4: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   5: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   6: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   7: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   8: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   9: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   10: {'mark': 6.142857142857143, 'error': 0.14285714285714324},
#   11: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   12: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   13: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   14: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   15: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   16: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   17: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   18: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   19: {'mark': 5.857142857142857, 'error': 0.14285714285714324},
#   20: {'mark': 5.857142857142857, 'error': 0.14285714285714324}}}
